# %% [markdown]
# This code employs the loss function as defined in the paper!

# %%
import numpy as np
np.set_printoptions(precision=4)
import matplotlib.pyplot as plt
import matplotlib as mpl

from scipy.stats import multivariate_normal as mvn
from scipy.special import iv
from scipy.ndimage import spline_filter, map_coordinates
mpl.rcParams['axes.linewidth'] = 3
mpl.rcParams['axes.titlesize'] = 20
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['axes.titlepad'] = 8.0
mpl.rcParams['xtick.major.size'] = 6
mpl.rcParams['xtick.major.width'] = 3
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.major.size'] = 6
mpl.rcParams['ytick.major.width'] = 3
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams['lines.markersize'] = 5
mpl.rcParams['lines.linewidth'] = 5
mpl.rcParams['legend.fontsize'] = 15

# %%
def distribution(x, y, x0, y0, mu_theta, sigma, kappa):
    gaussian = np.exp(-((x - x0)**2 + (y - y0)**2) / (2 * sigma**2))
    theta = np.arctan2(y - y0, x - x0)
    angular = np.exp(kappa * np.cos(theta - mu_theta))
    norm = 1 / (2 * np.pi * iv(0, kappa) * sigma**2)
    dist = gaussian * norm * angular
    return dist

# %%
boundary_shift = 1. ### Increase boundary to better deal with constraints keep in mind that in this case you also have to increase the number of coefficients to allow for appropriate results
L = [.5 * boundary_shift,.5 * boundary_shift] ### lower = -L assumed
### Grid
N_orig = 32 ### Change this to increase number of coeffs Also make sure the nmber of coeffs is appropraite for the sensor measure
 # shifts the boundary by this factor see below. Used to deal with the periodic boundary constraints of the FFT
x_orig = np.linspace(-L[0] * boundary_shift, L[0] * boundary_shift, N_orig)
y_orig = np.linspace(-L[1] * boundary_shift, L[1] * boundary_shift, N_orig)
X_orig, Y_orig = np.meshgrid(x_orig, y_orig)

### Params of precomputed distribution 
sigma = 0.1 ### Make sure when changed to also change the number of coeffs to represent the new distribution accuratly in Fourier domain
kappa = 10

## Inital position
x0 = 0.0
y0 = 0.0
mu_theta = 0.0

# %%
###### Precompute ####
Z_original = distribution(X_orig, Y_orig, x0, y0, mu_theta, sigma, kappa)

### Zero padding change N > N_orig to add padding
N = N_orig
x = np.linspace(-L[0] * boundary_shift * N / N_orig, L[0] * boundary_shift * N / N_orig, N)
y = np.linspace(-L[1]* boundary_shift * N / N_orig, L[1] * boundary_shift * N / N_orig, N)
X, Y = np.meshgrid(x, y)
dx = x[1] - x[0]
dy = y[1] - y[0]
Z_padded = np.zeros((N, N))
idx_start = (N - N_orig) // 2
idx_end = idx_start + N_orig
Z_padded[idx_start:idx_end, idx_start:idx_end] = Z_original

# Apply fftshift in spatial domain
Z_shifted = np.fft.fftshift(Z_padded)

# Compute FFT with orthonormal normalization (divide by N)
F = np.fft.fft2(Z_shifted, norm='ortho')
F = np.fft.fftshift(F)  # Shift DC to center
freq_x = np.fft.fftshift(np.fft.fftfreq(N, dx))
freq_y = np.fft.fftshift(np.fft.fftfreq(N, dy))
Wx, Wy = np.meshgrid(freq_x, freq_y)
### dF/dk
dF_dkx = -1j * 2 * np.pi * np.fft.fftshift(np.fft.fft2(X * Z_shifted, norm='ortho'))
dF_dky = -1j * 2 * np.pi * np.fft.fftshift(np.fft.fft2(Y * Z_shifted, norm='ortho'))

def precompute_spline(F, dF_dkx, dF_dky, order=5):
    """
    Precompute spline coefficients ONCE.
    Returns the filtered arrays.
    """
    F_spline = spline_filter(F, order=order)
    dF_dkx_spline = spline_filter(dF_dkx, order=order)
    dF_dky_spline = spline_filter(dF_dky, order=order)
    return F_spline, dF_dkx_spline, dF_dky_spline
F, dF_dkx, dF_dky = precompute_spline(F, dF_dkx, dF_dky, order=5)

# %%
def get_coeffs_spline(
    x, 
    F_spline, dF_dkx_spline, dF_dky_spline, 
    Wx, Wy, freq_x, freq_y, dx, dy, N, order=5
):
    """
    Fast evaluation using spline-filtered data.
    """
    x.squeeze()
    theta = x[2]
    cos_alpha = np.cos(-theta)
    sin_alpha = np.sin(-theta)

    # 1. Rotate frequencies
    Wx_rot = Wx * cos_alpha - Wy * sin_alpha
    Wy_rot = Wx * sin_alpha + Wy * cos_alpha

    # 2. Map to index space for interpolation
    freq_x_map = (Wx_rot - freq_x[0]) / (freq_x[1] - freq_x[0])
    freq_y_map = (Wy_rot - freq_y[0]) / (freq_y[1] - freq_y[0])
    coords = np.array([freq_y_map, freq_x_map])

    # 3. Interpolate complex values (fast: prefiltered, prefilter=False)
    def interp(F_complex, coords):
        F_real = np.real(F_complex)
        F_imag = np.imag(F_complex)
        real = map_coordinates(F_real, coords, order=order, prefilter=False, mode='reflect')
        imag = map_coordinates(F_imag, coords, order=order, prefilter=False, mode='reflect')
        return real + 1j * imag

    F_rot = interp(F_spline, coords)
    dF_dkx_rot = interp(dF_dkx_spline, coords)
    dF_dky_rot = interp(dF_dky_spline, coords)

    F_rot = np.fft.ifftshift(F_rot)
    dF_dkx_rot = np.fft.ifftshift(dF_dkx_rot)
    dF_dky_rot = np.fft.ifftshift(dF_dky_rot)

    # 4. Exact translation in Fourier domain
    x0, y0 = x[0], x[1]
    kx = np.fft.fftfreq(N, d=dx)
    ky = np.fft.fftfreq(N, d=dy)
    kx_grid, ky_grid = np.meshgrid(kx, ky, indexing='ij')
    shift_factor = np.exp(-2j * np.pi * (kx_grid * x0 + ky_grid * y0))

    F_rot_shifted = F_rot * shift_factor
    dF_dx0 = -2j * np.pi * kx_grid * F_rot * shift_factor
    dF_dy0 = -2j * np.pi * ky_grid * F_rot * shift_factor

    # 5. Exact chain rule for rotation derivative
    dWx_dtheta = Wx * np.sin(-theta) + Wy * np.cos(-theta)
    dWy_dtheta = -Wx * np.cos(-theta) + Wy * np.sin(-theta)
    dF_dtheta = (dF_dkx_rot * dWx_dtheta + dF_dky_rot * dWy_dtheta) * shift_factor
    grad = np.stack([dF_dx0, dF_dy0, dF_dtheta])

    return F_rot_shifted[:,:,None], grad[:,:,:,None]

# %%
def get_coeffs_spline(
    x, 
    F_spline, dF_dkx_spline, dF_dky_spline, 
    Wx, Wy, freq_x, freq_y, dx, dy, N, order=5
):
    """
    Apply a rotation and translation to a fixed Fourier field (F_spline)
    for each pose in x = [3, N_agents], where each column is (x, y, theta).

    Returns:
        F_rot_shifted: (N, N, N_agents)
        grads: (3, N, N, N_agents)
    """
    N_agents = x.shape[1]
    theta = x[2]  # (N_agents,)
    x0, y0 = x[0], x[1]

    cos_theta = np.cos(-theta)
    sin_theta = np.sin(-theta)

    Wx_flat = Wx.ravel()  # (K,)
    Wy_flat = Wy.ravel()
    K = Wx_flat.shape[0]

    # Rotate frequency grid per agent
    Wx_rot = Wx_flat[None, :] * cos_theta[:, None] - Wy_flat[None, :] * sin_theta[:, None]  # (N_agents, K)
    Wy_rot = Wx_flat[None, :] * sin_theta[:, None] + Wy_flat[None, :] * cos_theta[:, None]  # (N_agents, K)

    # Map rotated frequencies to index space
    fx0, fx1 = freq_x[0], freq_x[1]
    fy0, fy1 = freq_y[0], freq_y[1]
    freq_x_map = (Wx_rot - fx0) / (fx1 - fx0)  # (N_agents, K)
    freq_y_map = (Wy_rot - fy0) / (fy1 - fy0)  # (N_agents, K)

    # Stack into (2, N_agents * K) for map_coordinates
    coords = np.stack([freq_y_map, freq_x_map], axis=0).reshape(2, -1)

    def interp_batched(F_complex):
        F_real = np.real(F_complex)
        F_imag = np.imag(F_complex)
        real_interp = map_coordinates(F_real, coords, order=order, prefilter=False, mode='reflect')
        imag_interp = map_coordinates(F_imag, coords, order=order, prefilter=False, mode='reflect')
        F_interp = real_interp + 1j * imag_interp  # (N_agents * K,)
        return F_interp.reshape(N_agents, *Wx.shape)  # (N_agents, N, N)

    # Interpolate field and derivatives
    F_rot = interp_batched(F_spline)
    dF_dkx_rot = interp_batched(dF_dkx_spline)
    dF_dky_rot = interp_batched(dF_dky_spline)

    # Apply ifftshift
    F_rot = np.fft.ifftshift(F_rot, axes=(-2, -1))
    dF_dkx_rot = np.fft.ifftshift(dF_dkx_rot, axes=(-2, -1))
    dF_dky_rot = np.fft.ifftshift(dF_dky_rot, axes=(-2, -1))

    # Translation in Fourier domain
    kx = np.fft.fftfreq(N, d=dx)
    ky = np.fft.fftfreq(N, d=dy)
    kx_grid, ky_grid = np.meshgrid(kx, ky, indexing='ij')  # (N, N)

    phase = -2j * np.pi * (
        x0[:, None, None] * kx_grid[None, :, :] +
        y0[:, None, None] * ky_grid[None, :, :]
    )  # (N_agents, N, N)
    shift = np.exp(phase)

    F_rot_shifted = F_rot * shift  # (N_agents, N, N)

    # Derivatives w.r.t x0, y0
    dF_dx0 = -2j * np.pi * kx_grid[None, :, :] * F_rot * shift
    dF_dy0 = -2j * np.pi * ky_grid[None, :, :] * F_rot * shift

    # Derivative w.r.t theta (rotation)
    dWx_dtheta = Wx[None, :, :] * np.sin(-theta)[:, None, None] + Wy[None, :, :] * np.cos(-theta)[:, None, None]
    dWy_dtheta = -Wx[None, :, :] * np.cos(-theta)[:, None, None] + Wy[None, :, :] * np.sin(-theta)[:, None, None]

    dF_dtheta = (dF_dkx_rot * dWx_dtheta + dF_dky_rot * dWy_dtheta) * shift  # (N_agents, N, N)

    # Stack grads: (3, N, N, N_agents)
    grads = np.stack([dF_dx0, dF_dy0, dF_dtheta], axis=0)  # (3, N_agents, N, N)
    grads = np.moveaxis(grads, 1, -1)  # → (3, N, N, N_agents)

    # Return F_rot_shifted as (N, N, N_agents)
    F_rot_shifted = np.moveaxis(F_rot_shifted, 0, -1)

    return F_rot_shifted, grads

def get_coeffs_spline_batched(
    x,  # shape [3, N]
    F_spline, dF_dkx_spline, dF_dky_spline, 
    Wx, Wy, freq_x, freq_y, dx, dy, N_grid, order=5
):
    """
    Fast batched evaluation using spline-filtered data.
    x: array of shape [3, N] (x0, y0, theta per agent)
    Returns:
        F_rot_shifted: [N_grid, N_grid, N]
        dF_dx0, dF_dy0, dF_dtheta: each [N_grid, N_grid, N]
    """
    N = x.shape[1]
    theta = x[2, :]  # shape [N]
    cos_theta = np.cos(-theta)
    sin_theta = np.sin(-theta)

    # Pre-flatten Wx, Wy for easier broadcasting
    Wx_flat = Wx.ravel()[:, None]  # [M, 1]
    Wy_flat = Wy.ravel()[:, None]  # [M, 1]
    M = Wx_flat.shape[0]

    # 1. Rotate frequency grid for all thetas
    Wx_rot = Wx_flat * cos_theta - Wy_flat * sin_theta  # [M, N]
    Wy_rot = Wx_flat * sin_theta + Wy_flat * cos_theta  # [M, N]

    # 2. Map to index space
    freq_x_map = (Wx_rot - freq_x[0]) / (freq_x[1] - freq_x[0])  # [M, N]
    freq_y_map = (Wy_rot - freq_y[0]) / (freq_y[1] - freq_y[0])  # [M, N]

    coords = np.stack([freq_y_map, freq_x_map], axis=0)  # shape [2, M, N]
    coords_flat = coords.reshape(2, -1)  # [2, M*N]

    # 3. Interpolation helper (handles complex input)
    def interp(F_complex):
        F_real = np.real(F_complex)
        F_imag = np.imag(F_complex)

        real_interp = map_coordinates(F_real, coords_flat, order=order, prefilter=False, mode='reflect')
        imag_interp = map_coordinates(F_imag, coords_flat, order=order, prefilter=False, mode='reflect')

        return (real_interp + 1j * imag_interp).reshape(Wx.shape[0], Wx.shape[1], N)  # [N_grid, N_grid, N]

    F_rot = interp(F_spline)
    dF_dkx_rot = interp(dF_dkx_spline)
    dF_dky_rot = interp(dF_dky_spline)

    # 4. Inverse FFT shift to match spatial convention
    F_rot = np.fft.ifftshift(F_rot, axes=(0, 1))
    dF_dkx_rot = np.fft.ifftshift(dF_dkx_rot, axes=(0, 1))
    dF_dky_rot = np.fft.ifftshift(dF_dky_rot, axes=(0, 1))

    # 5. Exact translation shift in Fourier domain
    kx = np.fft.fftfreq(N_grid, d=dx)
    ky = np.fft.fftfreq(N_grid, d=dy)
    kx_grid, ky_grid = np.meshgrid(kx, ky, indexing='ij')  # [N_grid, N_grid]

    x0 = x[0, :]  # [N]
    y0 = x[1, :]  # [N]
    phase = -2j * np.pi * (kx_grid[..., None] * x0 + ky_grid[..., None] * y0)  # [N_grid, N_grid, N]
    shift_factor = np.exp(phase)

    F_shifted = F_rot * shift_factor
    dF_dx0 = -2j * np.pi * kx_grid[..., None] * F_rot * shift_factor
    dF_dy0 = -2j * np.pi * ky_grid[..., None] * F_rot * shift_factor

    # 6. Derivative w.r.t. rotation (chain rule)
    dWx_dtheta = Wx_flat * sin_theta + Wy_flat * cos_theta  # [M, N]
    dWy_dtheta = -Wx_flat * cos_theta + Wy_flat * sin_theta  # [M, N]

    dWx_dtheta = dWx_dtheta.reshape(Wx.shape[0], Wx.shape[1], N)
    dWy_dtheta = dWy_dtheta.reshape(Wy.shape[0], Wy.shape[1], N)

    dF_dtheta = (dF_dkx_rot * dWx_dtheta + dF_dky_rot * dWy_dtheta) * shift_factor

    return F_shifted, np.stack([dF_dx0, dF_dy0, dF_dtheta], axis=0)  # shape [3, N_grid, N_grid, N]

def get_coeffs_and_derivatives(x, F, dF_dkx, dF_dky, Wx, Wy, freq_x, freq_y, dx, dy, N):
    #F_rotated_shifted, dF_dx0, dF_dy0, dF_dtheta = get_coeffs(
    #    x, F, dF_dkx, dF_dky, Wx, Wy, freq_x, freq_y, dx, dy, N
    #)

    return get_coeffs_spline_batched(
    x, 
    F, dF_dkx, dF_dky, 
    Wx, Wy, freq_x, freq_y, dx, dy, N, order=5
)

# %%
pose1 = np.array([0.1, 0.3, np.pi/2])
pose2 = np.array([-0.2, -0.2, np.pi/6])
x = np.stack([pose1], axis=1)
F_rotated,dF = get_coeffs_and_derivatives(x, F, dF_dkx, dF_dky, Wx, Wy, freq_x, freq_y, dx, dy, N)
print(np.allclose(dF[:,:,:,0], dF[:,:,:,0]))
print(F_rotated.shape)
Z_rotated_padded = np.fft.ifft2(F_rotated[:,:,0], norm = 'ortho')
Z_rotated_padded = np.abs(Z_rotated_padded)
Z_rotated = np.fft.ifftshift(Z_rotated_padded)
Z_rotated = Z_rotated[idx_start:idx_end, idx_start:idx_end]
fig, (ax2) = plt.subplots(1, 1, figsize=(18, 5))
im2 = ax2.imshow(Z_rotated, extent=[-L[0] * boundary_shift, L[0] * boundary_shift, -L[1] * boundary_shift, L[1] * boundary_shift], origin='lower', cmap='viridis')
ax2.set_title('Fourier Rotated at μ_θ = π/3')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
plt.colorbar(im2, ax=ax2, label='Intensity')
plt.tight_layout()
plt.show()
## Check valid pdf
print(Z_rotated.sum() * dx * dy)
# Out:
# True
# (32, 32, 1)
# 0.992398118500992

# %%
# Define the target measure
mean1 = np.array([-.15, -.12])
cov1 = np.array([
    [0.01, 0.004],
    [0.004, 0.01]
])
w1 = 0.6

mean2 = np.array([0.18, -0.25])
cov2 = np.array([
    [0.005, -0.003],
    [-0.003, 0.005]
])
w2 = 0.2

mean3 = np.array([0.06, 0.14])
cov3 = np.array([
    [0.008, 0.0],
    [0.0, 0.004]
])

w3 = 0.1

mean4 = np.array([-.28, 0.24])
cov4 = np.array([
    [0.01, 0.004],
    [0.004, 0.01]
])
w4 = 0.1

def pdf(x):
    return w1 * mvn.pdf(x, mean1, cov1) + \
           w2 * mvn.pdf(x, mean2, cov2) + \
           w3 * mvn.pdf(x, mean3, cov3) + \
           w4 * mvn.pdf(x, mean4, cov4)

# %%
###### Precompute ####
points = np.stack([X_orig.ravel(), Y_orig.ravel()], axis=-1)
Z_target = pdf(points).reshape((N_orig, N_orig))

### Zero padding
N = N_orig
x = np.linspace(-L[0] * boundary_shift * N / N_orig, L[0]* boundary_shift* N / N_orig , N)
y = np.linspace(-L[1]* boundary_shift* N / N_orig , L[1]* boundary_shift* N / N_orig , N)
X, Y = np.meshgrid(x, y)
dx = x[1] - x[0]
dy = y[1] - y[0]
Z_target_padded = np.zeros((N, N))
idx_start = (N - N_orig) // 2
idx_end = idx_start + N_orig
Z_target_padded[idx_start:idx_end, idx_start:idx_end] = Z_target

# Apply fftshift in spatial domain
Z_target_shifted = np.fft.fftshift(Z_target_padded)

# Compute FFT with orthonormal normalization (divide by N)
F_target = np.fft.fft2(Z_target_shifted, norm='ortho')
F_target *= N * dx * dy

# %%
### Both should be roughly 1
print(F_target[0,0], F_rotated.squeeze()[0,0] * N * dx * dy)
# Out:
# (0.9987308119671141+0j) (0.980481582956545-6.846664367542669e-15j)

# %%
ks_dim1, ks_dim2 = np.meshgrid(
    np.arange(N_orig), np.arange(N_orig)
)
ks = np.array([ks_dim1.ravel(), ks_dim2.ravel()]).T
lamk_list = np.power(1.0 + np.linalg.norm(ks, axis=1), -3/2.0) # Fourier here no square in paper square??? 
lamk_list = lamk_list.reshape(N_orig, N_orig)

# %%
def boundary_penalty(dist, threshold, k=10.0, n=2):
    if dist > threshold:
        return 0.0
    else:
        return k * (1 - dist / threshold)**n

def adjust_control_with_nonlinear_penalty(xt, ut, L, boundary_threshold, ud, u_omega):
    x, y, theta = xt
    v, omega = ut

    dist_x_pos = L[0] - x
    dist_x_neg = x + L[0]
    dist_y_pos = L[1] - y
    dist_y_neg = y + L[1]

    omega_correction = 0.0

    # Positive x-boundary
    if dist_x_pos < boundary_threshold and np.cos(theta) > 0:
        penalty = boundary_penalty(dist_x_pos, boundary_threshold)
        omega_correction += penalty  # turn left

    # Negative x-boundary
    if dist_x_neg < boundary_threshold and np.cos(theta) < 0:
        penalty = boundary_penalty(dist_x_neg, boundary_threshold)
        omega_correction -= penalty  # turn right

    # Positive y-boundary
    if dist_y_pos < boundary_threshold and np.sin(theta) > 0:
        penalty = boundary_penalty(dist_y_pos, boundary_threshold)
        omega_correction -= penalty  # turn right

    # Negative y-boundary
    if dist_y_neg < boundary_threshold and np.sin(theta) < 0:
        penalty = boundary_penalty(dist_y_neg, boundary_threshold)
        omega_correction += penalty  # turn left

    omega += omega_correction

    # Optionally softly reduce forward velocity when very close
    min_dist = min(dist_x_pos, dist_x_neg, dist_y_pos, dist_y_neg)
    if min_dist < boundary_threshold:
        v = v * (min_dist / boundary_threshold)  # scale down linearly

    # Clip velocities
    v = np.clip(v, -ud, ud)
    omega = np.clip(omega, -u_omega, u_omega)

    return np.array([v, omega])

# %%
dt = 0.01
tsteps = 25001
ud = .2 # max desired linear velocity
u_omega = np.pi # desired max angular velocity

def dyn(xt, ut):
    x, y, theta = xt
    v, omega = ut
    return np.array([
        v * np.cos(theta),
        v * np.sin(theta),
        omega
    ])

def step(xt, ut):
    return xt + dt * dyn(xt, ut)
# Initialize state [x, y, theta]
N_agents = 5
F_target *= N_agents
xt = np.vstack([
    np.random.uniform(-0.5, 0.5, size=N_agents),       # x0
    np.random.uniform(-0.5, 0.5, size=N_agents),       # y0
    np.random.uniform(-np.pi, np.pi, size=N_agents)    # theta
])

x_traj = np.zeros((tsteps, 3, N_agents))
ck_list_update = np.zeros((*F_target.shape, N_agents), dtype=np.complex128)
metric_log = []    
ck_list_update_real = np.zeros((*F_target.shape, N_agents), dtype=np.float64)
ck_list_update_imag = np.zeros((*F_target.shape, N_agents), dtype=np.float64)
for t in range(tsteps):
    xt = xt.real
    fk_xt_all, dfk_xt_all = get_coeffs_and_derivatives(xt, F, dF_dkx, dF_dky, Wx, Wy, freq_x, freq_y, dx, dy, N)

    fk_xt_all *= N * dx * dy # Normalize
    dfk_xt_all *= N * dx * dy # Normalize
    theta = xt[2,:]

    # Accumulate coefficients over time
    ck_list_update += fk_xt_all * dt
    # Compute numerator for gradient step
    empirical_measure = np.sum(ck_list_update / (t*dt + dt), axis = -1) 
    S_k = lamk_list * (empirical_measure - F_target)

    # Compute weighted sum of numerator * gradient
    term = (
    S_k.real[None, :, :, None] * dfk_xt_all.real +
    S_k.imag[None, :, :, None] * dfk_xt_all.imag
    )  # shape: (3, N, N)

    bt = np.sum(term, axis=(1, 2))
    b_tilde = np.array([
        bt[0] * np.cos(theta) + bt[1] * np.sin(theta),
        bt[2]
    ])
    norm_b_tilde = np.linalg.norm(b_tilde)

    if norm_b_tilde < 1e-8:
        ut = np.array([0.0, 0.0])
    else:
        matrix = np.array([[-ud, 0], [0, -u_omega]])
        b_unit = b_tilde / norm_b_tilde
        v, omega = matrix @ b_unit
        v = np.clip(v, -ud, ud)
        omega = np.clip(omega, -u_omega, u_omega)
        ut = np.array([v, omega])

    ##### Steer away from boundary this dramiatically reduces convergence opposed to periodic boundaries
    #ut = adjust_control_with_nonlinear_penalty(xt, ut, L, boundary_threshold=0.1, ud=ud, u_omega=u_omega)

    xt = step(xt, ut)
    x_traj[t] = xt.copy()
    

    ### Problems with perodicity of Fourier transform under unicycle model! For the Spherical sets we defined a barrier function cf. Simulation\notebooks\smc_ergodic_unicycle.ipynb
    xt[0] = (xt[0] + L[0]) % 1 - L[0] 
    xt[1] = (xt[1] + L[1]) % 1 - L[1]

    # Calculate ergodic metric error (use full complex parts)
    err = lamk_list * (empirical_measure - F_target) / N_agents
    err_real = np.square(err.real)
    err_imag = np.square(err.imag)
    erg_metric_real = np.sum(err_real)
    erg_metric_imag = np.sum(err_imag)
    if t % 1000 == 0:
        print(f"Step {t}, Position: {xt[:2,0].real}, Heading: {xt[2,0].real:.3f}, Metric real: {erg_metric_real:.5f}, Metric imag: {erg_metric_imag:.5f}")
# Out:
# Step 0, Position: [ 0.2572 -0.1182], Heading: -2.718, Metric real: 0.08452, Metric imag: 0.08902
# Step 1000, Position: [ 0.1278 -0.017 ], Heading: -13.996, Metric real: 0.00705, Metric imag: 0.00198
# Step 2000, Position: [-0.2341  0.1148], Heading: -16.489, Metric real: 0.00319, Metric imag: 0.00064
# Step 3000, Position: [-0.2581  0.0694], Heading: -19.240, Metric real: 0.00091, Metric imag: 0.00107
# Step 4000, Position: [-0.4097 -0.042 ], Heading: -34.603, Metric real: 0.00107, Metric imag: 0.00048
# Step 5000, Position: [-0.3143 -0.0477], Heading: -36.502, Metric real: 0.00073, Metric imag: 0.00033
# Step 6000, Position: [-0.3456  0.2198], Heading: -35.361, Metric real: 0.00062, Metric imag: 0.00048
# Step 7000, Position: [-0.2456  0.2438], Heading: -33.481, Metric real: 0.00062, Metric imag: 0.00020
# Step 8000, Position: [-0.1748  0.1936], Heading: -33.710, Metric real: 0.00050, Metric imag: 0.00014
# Step 9000, Position: [-0.1738  0.1951], Heading: -33.626, Metric real: 0.00051, Metric imag: 0.00015
# Step 10000, Position: [-0.1745  0.194 ], Heading: -33.541, Metric real: 0.00051, Metric imag: 0.00014
# Step 11000, Position: [-0.1741  0.1956], Heading: -33.556, Metric real: 0.00050, Metric imag: 0.00014
# Step 12000, Position: [-0.1745  0.1962], Heading: -33.474, Metric real: 0.00049, Metric imag: 0.00015
# Step 13000, Position: [-0.1718  0.204 ], Heading: -33.369, Metric real: 0.00046, Metric imag: 0.00024
# Step 14000, Position: [-0.1684  0.2202], Heading: -33.418, Metric real: 0.00048, Metric imag: 0.00019
# Step 15000, Position: [-0.1772  0.22  ], Heading: -33.314, Metric real: 0.00050, Metric imag: 0.00017
# Step 16000, Position: [-0.1924  0.1643], Heading: -33.056, Metric real: 0.00052, Metric imag: 0.00015
# Step 17000, Position: [-0.3307  0.1317], Heading: -30.829, Metric real: 0.00055, Metric imag: 0.00025
# Step 18000, Position: [-0.2872  0.1373], Heading: -31.378, Metric real: 0.00063, Metric imag: 0.00043
# Step 19000, Position: [ 0.0034 -0.2352], Heading: -32.028, Metric real: 0.00057, Metric imag: 0.00046
# Step 20000, Position: [-0.2139 -0.3458], Heading: -30.760, Metric real: 0.00051, Metric imag: 0.00031
# Step 21000, Position: [-0.2507 -0.3699], Heading: -30.759, Metric real: 0.00049, Metric imag: 0.00018
# Step 22000, Position: [-0.1566 -0.2563], Heading: -30.770, Metric real: 0.00045, Metric imag: 0.00010
# Step 23000, Position: [-0.1759 -0.2682], Heading: -30.903, Metric real: 0.00043, Metric imag: 0.00011
# Step 24000, Position: [-0.1925 -0.2707], Heading: -31.692, Metric real: 0.00047, Metric imag: 0.00013
# Step 25000, Position: [-0.1836 -0.2701], Heading: -30.973, Metric real: 0.00052, Metric imag: 0.00013

# %%
#### Plot the results
coeffs = np.sum(ck_list_update / (t*dt + dt), axis = -1) / N_agents
Z_rotated_padded = np.fft.ifft2(coeffs, norm = 'forward') / boundary_shift**2
Z_rotated_padded = np.abs(Z_rotated_padded)
Z_rotated = np.fft.ifftshift(Z_rotated_padded)
Z_rotated = Z_rotated[idx_start:idx_end, idx_start:idx_end]
fig, (ax2) = plt.subplots(1, 1, figsize=(18, 5))
im2 = ax2.imshow(Z_rotated, extent=[-L[0] * boundary_shift, L[0] * boundary_shift, -L[1] * boundary_shift , L[1] * boundary_shift], origin='lower', cmap='viridis')
ax2.set_title('Fourier Rotated at μ_θ = π/3')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
plt.colorbar(im2, ax=ax2, label='Intensity')
plt.tight_layout()
plt.show()
## Check valid pdf
print(Z_rotated.sum() * dx * dy)
fig, axes = plt.subplots(1, 2, figsize=(9,5), dpi=70, tight_layout=True)
ax = axes[0]
ax.set_aspect('equal')
ax.set_xlim(-L[0], L[0])
ax.set_ylim(-L[1], L[1])
ax.set_title(f'Original PDF')
ax.contourf(X_orig, Y_orig, Z_target.reshape(X_orig.shape), cmap='Reds')
ax.plot(x_traj[::10, 0,0], x_traj[::10, 1,0], linestyle='-', marker='', color='k', alpha=0.1, label='Trajectory')
ax.plot(x_traj[0, 0,0], x_traj[0, 1,0], linestyle='', marker='o', markersize=15, color='C2', alpha=1.0, label='Initial state')
ax.legend(loc='upper right')

ax2 = axes[1]
ax2.set_aspect('equal')
ax.set_xlim(-L[0], L[0])
ax.set_ylim(-L[1], L[1])
ax2.set_title(f'Empirical Density')
ax2.contourf(X_orig, Y_orig,
             Z_rotated.reshape(X_orig.shape),
             cmap='Reds')
plt.tight_layout()
plt.show()
# Out:
# 1.045940845142203

# %%
# Generate animation (takes about 1 minute)
from IPython.display import HTML
from matplotlib import animation

fig, ax = plt.subplots(1, 1, figsize=(6,7), dpi=70, tight_layout=True)
ax.set_aspect('equal')
ax.set_xlim(-.5, .5)
ax.set_ylim(-.5, .5)
ax.set_xlabel('X (m)')
ax.set_ylabel('Y (m)')
ax.contourf(X_orig, Y_orig, Z_target.reshape(X_orig.shape), cmap='Reds')

robot_traj, = ax.plot([], [], linestyle='-', marker='', color='k', alpha=0.2)
robot_state, = ax.plot(x_traj[0,0], x_traj[0,1], linestyle='', marker='o', markersize=15, color='C2')

def update_plot(frame):
    t = int(frame * 10)
    robot_state.set_data(
        np.array([x_traj[t][0]]), np.array([x_traj[t][1]])
    )
    robot_traj.set_data(
        x_traj[:t,0][::10], x_traj[:t,1][::10]
    )

    return robot_state, robot_traj,

#ani = animation.FuncAnimation(fig, update_plot, frames=int(tsteps/10)-1, blit=True, interval=30, repeat=False)
#video = ani.to_html5_video()
#HTML(video)
