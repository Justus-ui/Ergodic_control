# %%
import numpy as np
np.set_printoptions(precision=4)
import matplotlib.pyplot as plt
import matplotlib as mpl

from scipy.stats import multivariate_normal as mvn
from scipy.special import iv
from scipy.ndimage import map_coordinates

mpl.rcParams['axes.linewidth'] = 3
mpl.rcParams['axes.titlesize'] = 20
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['axes.titlepad'] = 8.0
mpl.rcParams['xtick.major.size'] = 6
mpl.rcParams['xtick.major.width'] = 3
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.major.size'] = 6
mpl.rcParams['ytick.major.width'] = 3
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams['lines.markersize'] = 5
mpl.rcParams['lines.linewidth'] = 5
mpl.rcParams['legend.fontsize'] = 15

# %%
def distribution(x, y, x0, y0, mu_theta, sigma, kappa):
    gaussian = np.exp(-((x - x0)**2 + (y - y0)**2) / (2 * sigma**2))
    theta = np.arctan2(y - y0, x - x0)
    angular = np.exp(kappa * np.cos(theta - mu_theta))
    norm = 1 / (2 * np.pi * iv(0, kappa) * sigma**2)
    dist = gaussian * norm * angular
    return dist

# %%
L = [.5,.5] ### lower = 0 assumed
### Grid
N_orig = 16
x_orig = np.linspace(-L[0], L[0], N_orig)
y_orig = np.linspace(-L[1], L[1], N_orig)
X_orig, Y_orig = np.meshgrid(x_orig, y_orig)

### Params of precomputed distribution 
sigma = 0.1
kappa = 5.0

## Inital position
x0 = 0.0
y0 = 0.0
mu_theta = 0.0

# %%
###### Precompute ####
Z_original = distribution(X_orig, Y_orig, x0, y0, mu_theta, sigma, kappa)

### Zero padding change N > N_orig to add padding
N = N_orig
x = np.linspace(-L[0] * N / N_orig, L[0]* N / N_orig, N)
y = np.linspace(-L[1] * N / N_orig, L[1]* N / N_orig, N)
X, Y = np.meshgrid(x, y)
dx = x[1] - x[0]
dy = y[1] - y[0]
Z_padded = np.zeros((N, N))
idx_start = (N - N_orig) // 2
idx_end = idx_start + N_orig
Z_padded[idx_start:idx_end, idx_start:idx_end] = Z_original

# Apply fftshift in spatial domain
Z_shifted = np.fft.fftshift(Z_padded)

# Compute FFT with orthonormal normalization (divide by N)
F = np.fft.fft2(Z_shifted, norm='ortho')
F = np.fft.fftshift(F)  # Shift DC to center
freq_x = np.fft.fftshift(np.fft.fftfreq(N, dx))
freq_y = np.fft.fftshift(np.fft.fftfreq(N, dy))
Wx, Wy = np.meshgrid(freq_x, freq_y)

# %%
import numpy as np
from scipy.ndimage import map_coordinates, gaussian_filter
def numerical_dtheta(x, F, Wx, Wy, freq_x, freq_y, dx, dy, N, eps=1e-5):
    x_plus = x.copy()
    x_minus = x.copy()
    x_plus[2] += eps
    x_minus[2] -= eps

    F_plus, _,_ = get_coeffs(x_plus, F, Wx, Wy, freq_x, freq_y, dx, dy, N)
    F_minus, _,_ = get_coeffs(x_minus, F, Wx, Wy, freq_x, freq_y, dx, dy, N)
    numerical_derivative = (F_plus - F_minus) / (2 * eps)


    return numerical_derivative

def get_coeffs(x, F, Wx, Wy, freq_x, freq_y, dx, dy, N):
    # 1. Rotation by theta
    mu_theta_new = x[2]
    cos_alpha = np.cos(-mu_theta_new)
    sin_alpha = np.sin(-mu_theta_new)
    Wx_rot = Wx * cos_alpha - Wy * sin_alpha
    Wy_rot = Wx * sin_alpha + Wy * cos_alpha
    # 2. Map rotated frequencies to index space for interpolation
    freq_x_map = (Wx_rot - freq_x[0]) / (freq_x[1] - freq_x[0])
    freq_y_map = (Wy_rot - freq_y[0]) / (freq_y[1] - freq_y[0])
    coords = np.array([freq_y_map, freq_x_map])
    # 3. Interpolate rotated Fourier image
    F_real = np.real(F)
    F_imag = np.imag(F)
    F_rotated_real = map_coordinates(F_real, coords, order=5, mode='constant', cval=0)
    F_rotated_imag = map_coordinates(F_imag, coords, order=5, mode='constant', cval=0)
    F_rotated = F_rotated_real + 1j * F_rotated_imag
    F_rotated = np.fft.ifftshift(F_rotated)
    # 4. Shift (translation)
    x0, y0 = x[0], x[1]
    kx = np.fft.fftfreq(N, d=dx)
    ky = np.fft.fftfreq(N, d=dy)
    kx_grid, ky_grid = np.meshgrid(kx, ky, indexing='ij')
    shift_factor = np.exp(-2j * np.pi * (kx_grid * x0 + ky_grid * y0))
    F_rotated_shifted = F_rotated * shift_factor
    # 5. Translation derivatives
    dF_dx0 = -2j * np.pi * kx_grid * F_rotated * shift_factor
    dF_dy0 = -2j * np.pi * ky_grid * F_rotated * shift_factor
    return F_rotated_shifted, dF_dx0, dF_dy0

def get_coeffs_and_derivatives(x, F, Wx, Wy, freq_x, freq_y, dx, dy, N, use_gradient_np = False):
    F_rotated_shifted, dF_dx0, dF_dy0 = get_coeffs(x, F, Wx, Wy, freq_x, freq_y, dx, dy, N)
    ## We use numerical integration as we havent found an efficient method to compute them using the chain rule as in the paper, the function f(k_x, k_y) and its derivatives should be learned apriori if speed is needed
    dF_dtheta_numeric = numerical_dtheta(x, F, Wx, Wy, freq_x, freq_y, dx, dy, N) 
    return F_rotated_shifted, np.stack([dF_dx0, dF_dy0, dF_dtheta_numeric], axis=0)

# %%
x = np.array([0.1,0.3, np.pi/2])
F_rotated,dF = get_coeffs_and_derivatives(x, F, Wx, Wy, freq_x, freq_y, dx, dy, N)
Z_rotated_padded = np.fft.ifft2(F_rotated, norm = 'ortho')
Z_rotated_padded = np.abs(Z_rotated_padded)
Z_rotated = np.fft.ifftshift(Z_rotated_padded)
Z_rotated = Z_rotated[idx_start:idx_end, idx_start:idx_end]
fig, (ax2) = plt.subplots(1, 1, figsize=(18, 5))
im2 = ax2.imshow(Z_rotated, extent=[-0.5, 0.5, -0.5, 0.5], origin='lower', cmap='viridis')
ax2.set_title('Fourier Rotated at μ_θ = π/3')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
plt.colorbar(im2, ax=ax2, label='Intensity')
plt.tight_layout()
plt.show()
## Check valid pdf
print(Z_rotated.sum() * dx * dy)
# Out:
# 1.0341774255846448

# %%
# Define the target measure
mean1 = np.array([0.0, 0.0])
cov1 = np.array([
    [0.01, 0.004],
    [0.004, 0.01]
])
w1 = 0.25

mean2 = np.array([-0.2, -0.1])
cov2 = np.array([
    [0.005, -0.003],
    [-0.003, 0.005]
])
w2 = 0.25

mean3 = np.array([-0.3, 0.3])
cov3 = np.array([
    [0.008, 0.0],
    [0.0, 0.004]
])

w3 = 0.25

mean4 = np.array([0.22, 0.3])
cov4 = np.array([
    [0.01, 0.004],
    [0.004, 0.01]
])
w4 = 0.25

def pdf(x):
    return w1 * mvn.pdf(x, mean1, cov1) + \
           w2 * mvn.pdf(x, mean2, cov2) + \
           w3 * mvn.pdf(x, mean3, cov3) + \
           w4 * mvn.pdf(x, mean4, cov4)

# %%
###### Precompute ####
points = np.stack([X_orig.ravel(), Y_orig.ravel()], axis=-1)
Z_target = pdf(points).reshape((N_orig, N_orig))

### Zero padding
N = N_orig
x = np.linspace(-L[0] * N / N_orig, L[0]* N / N_orig, N)
y = np.linspace(-L[1]* N / N_orig, L[1]* N / N_orig, N)
X, Y = np.meshgrid(x, y)
dx = x[1] - x[0]
dy = y[1] - y[0]
Z_target_padded = np.zeros((N, N))
idx_start = (N - N_orig) // 2
idx_end = idx_start + N_orig
Z_target_padded[idx_start:idx_end, idx_start:idx_end] = Z_target

# Apply fftshift in spatial domain
Z_target_shifted = np.fft.fftshift(Z_target_padded)

# Compute FFT with orthonormal normalization (divide by N)
F_target = np.fft.fft2(Z_target_shifted, norm='ortho')
F_target *= N * dx * dy

# %%
### Both should be roughly 1
print(F_target[0,0], F_rotated[0,0] * N * dx * dy)
# Out:
# (0.9967070526998152+0j) (0.9210227022689593-5.86010562660777e-16j)

# %%
### Weights of respective Fourier coefficients
s = -1.5  # Sobolev order
kx = np.fft.fftfreq(N, d=dx)
ky = np.fft.fftfreq(N, d=dy)
kx_grid, ky_grid = np.meshgrid(kx, ky, indexing='ij')
k_squared = kx_grid**2 + ky_grid**2
lamk_list = (1 + (2 * np.pi)**2 * k_squared)**s

# %%
dt = 0.01
tsteps = 200001
ud = 0.5  # max desired linear velocity
u_omega = np.pi # desired max angular velocity

def dyn(xt, ut):
    x, y, theta = xt
    v, omega = ut
    return np.array([
        v * np.cos(theta),
        v * np.sin(theta),
        omega
    ])

def step(xt, ut):
    return xt + dt * dyn(xt, ut)
# Initialize state [x, y, theta]
xt = np.array([np.random.uniform(-0.5, 0.5), np.random.uniform(-0.5, 0.5), 0.0])
x_traj = np.zeros((tsteps, 3))
ck_list_update = np.zeros_like(F_target, dtype=np.float64)
ck_list_update_imag = np.zeros_like(F_target, dtype=np.float64)
metric_log = []    
barrier_weight = 0.0

for t in range(tsteps):
    xt = xt.real
    fk_xt_all, dfk_xt_all = get_coeffs_and_derivatives(xt, F, Wx, Wy, freq_x, freq_y, dx, dy, N, use_gradient_np=False)

    fk_xt_all *= N * dx * dy # Normalize
    dfk_xt_all *= N * dx * dy # Normalize
    theta = xt[2]

    # Accumulate coefficients over time
    ck_list_update += fk_xt_all.real * dt
    ck_list_update_imag += fk_xt_all.imag * dt

    # Compute numerator for gradient step
    numerator = (ck_list_update / (t * dt + dt)) - F_target.real
    numerator_imag = (ck_list_update_imag / (t * dt + dt)) - F_target.imag

    # Compute weighted sum of numerator * gradient
    bt = np.sum(lamk_list * numerator * dfk_xt_all.real, axis=(1, 2))
    bt_imag = np.sum(lamk_list * numerator_imag * dfk_xt_all.imag, axis=(1, 2))


    # Combine real and imaginary parts to get gradient components
    b_tilde_real = np.array([
        bt[0] * np.cos(theta) + bt[1] * np.sin(theta),
        bt[2]
    ])
    b_tilde_imag = np.array([
        bt_imag[0] * np.cos(theta) + bt_imag[1] * np.sin(theta),
        bt_imag[2]
    ])

    b_tilde =  b_tilde_real +  b_tilde_imag
    norm_b_tilde = np.linalg.norm(b_tilde)

    if norm_b_tilde < 1e-8:
        ut = np.array([0.0, 0.0])
    else:
        matrix = np.array([[-ud, 0], [0, -u_omega]])
        b_unit = b_tilde / norm_b_tilde
        v, omega = matrix @ b_unit
        v = np.clip(v, -ud, ud)
        omega = np.clip(omega, -u_omega, u_omega)
        ut = np.array([v, omega])

    xt = step(xt, ut)
    x_traj[t] = xt.copy()

    ### Problems with perodicity of Fourier transform under unicycle model! For the Spherical sets we defined a barrier function cf. Simulation\notebooks\smc_ergodic_unicycle.ipynb
    xt[0] = (xt[0] + 0.5) % 1 - 0.5
    xt[1] = (xt[1] + 0.5) % 1 - 0.5

    # Calculate ergodic metric error (use full complex parts)
    err_real = np.square(F_target.real - ck_list_update / (t * dt + dt))
    err_imag = np.square((F_target.imag - ck_list_update_imag) / (t * dt + dt))
    erg_metric_real = np.sum(err_real)
    erg_metric_imag = np.sum(err_imag)
    metric_log.append(erg_metric_real + 1j* erg_metric_imag)
    if t % 1000 == 0:
        print(f"Step {t}, Position: {xt[:2].real}, Heading: {xt[2].real:.3f}, Metric real: {erg_metric_real:.5f}, Metric imag: {erg_metric_imag:.5f}")
# Out:
# Step 0, Position: [-0.2145  0.0375], Heading: 0.000, Metric real: 13.54924, Metric imag: 12197.49949
# Step 1000, Position: [-0.1616 -0.3183], Heading: 0.525, Metric real: 1.52337, Metric imag: 1.00913
# Step 2000, Position: [ 0.3378 -0.0373], Heading: -1.273, Metric real: 1.11115, Metric imag: 0.79914
# Step 3000, Position: [0.2098 0.1342], Heading: -1.361, Metric real: 0.74021, Metric imag: 0.70568
# Step 4000, Position: [-0.3674 -0.2132], Heading: -4.520, Metric real: 0.75491, Metric imag: 0.63751
# Step 5000, Position: [-0.3159 -0.2857], Heading: -4.478, Metric real: 0.75342, Metric imag: 0.57811
# Step 6000, Position: [-0.24   -0.2794], Heading: -4.518, Metric real: 0.79650, Metric imag: 0.63316
# Step 7000, Position: [ 0.0957 -0.3662], Heading: -4.532, Metric real: 0.66021, Metric imag: 0.65118
# Step 8000, Position: [ 0.1934 -0.313 ], Heading: -3.720, Metric real: 0.59835, Metric imag: 0.58686
# Step 9000, Position: [-0.0492 -0.0113], Heading: -3.049, Metric real: 0.50118, Metric imag: 0.58707
# Step 10000, Position: [0.0718 0.2203], Heading: -4.511, Metric real: 0.46143, Metric imag: 0.55063
# Step 11000, Position: [ 0.0238 -0.3131], Heading: -4.528, Metric real: 0.47519, Metric imag: 0.54001
# Step 12000, Position: [-0.0186 -0.4221], Heading: -6.076, Metric real: 0.51044, Metric imag: 0.56652
# Step 13000, Position: [0.1964 0.168 ], Heading: -4.514, Metric real: 0.48195, Metric imag: 0.55463
# Step 14000, Position: [0.1845 0.2458], Heading: -4.496, Metric real: 0.50370, Metric imag: 0.50724
# Step 15000, Position: [ 0.0851 -0.0021], Heading: -1.387, Metric real: 0.50867, Metric imag: 0.54175
# Step 16000, Position: [ 0.0947 -0.0892], Heading: -1.369, Metric real: 0.47238, Metric imag: 0.55007
# Step 17000, Position: [ 0.0775 -0.1817], Heading: -1.366, Metric real: 0.52211, Metric imag: 0.58878
# Step 18000, Position: [ 0.0558 -0.2067], Heading: -1.395, Metric real: 0.56695, Metric imag: 0.59242
# Step 19000, Position: [ 0.0214 -0.1985], Heading: -1.361, Metric real: 0.59099, Metric imag: 0.62667
# Step 20000, Position: [-0.0184 -0.1811], Heading: -1.365, Metric real: 0.57932, Metric imag: 0.67069
# Step 21000, Position: [0.4485 0.3226], Heading: -1.356, Metric real: 0.56282, Metric imag: 0.62931
# Step 22000, Position: [0.452  0.2154], Heading: -1.373, Metric real: 0.57775, Metric imag: 0.61645
# Step 23000, Position: [ 0.3072 -0.4544], Heading: 0.276, Metric real: 0.53133, Metric imag: 0.64261
# Step 24000, Position: [ 0.3028 -0.4625], Heading: 0.218, Metric real: 0.51349, Metric imag: 0.70520
# Step 25000, Position: [ 0.2754 -0.4754], Heading: 0.195, Metric real: 0.52707, Metric imag: 0.78781
# Step 26000, Position: [-0.0659 -0.4997], Heading: 0.199, Metric real: 0.56614, Metric imag: 0.76931
# Step 27000, Position: [ 0.3606 -0.3857], Heading: 0.202, Metric real: 0.62184, Metric imag: 0.76284
# Step 28000, Position: [ 0.3056 -0.3881], Heading: 0.201, Metric real: 0.63605, Metric imag: 0.82363
# Step 29000, Position: [-0.1095 -0.4313], Heading: 0.196, Metric real: 0.64827, Metric imag: 0.87211
# Step 30000, Position: [-0.0956 -0.4168], Heading: 0.193, Metric real: 0.66264, Metric imag: 0.87900
# Step 31000, Position: [-0.0801 -0.4026], Heading: 0.193, Metric real: 0.68210, Metric imag: 0.91080
# Step 32000, Position: [-0.0672 -0.3861], Heading: 0.207, Metric real: 0.70515, Metric imag: 0.96040
# Step 33000, Position: [-0.0767 -0.3628], Heading: 0.194, Metric real: 0.71810, Metric imag: 1.01862
# Step 34000, Position: [-0.0823 -0.3354], Heading: 0.200, Metric real: 0.71121, Metric imag: 1.07607
# Step 35000, Position: [ 0.3075 -0.2183], Heading: 0.184, Metric real: 0.73137, Metric imag: 1.04232
# Step 36000, Position: [ 0.2498 -0.2155], Heading: 0.178, Metric real: 0.76577, Metric imag: 1.02279
# Step 37000, Position: [-0.1158 -0.2666], Heading: 0.198, Metric real: 0.73922, Metric imag: 1.00997
# Step 38000, Position: [-0.1124 -0.2751], Heading: 0.195, Metric real: 0.66874, Metric imag: 1.01924
# Step 39000, Position: [-0.0951 -0.2652], Heading: 0.196, Metric real: 0.62174, Metric imag: 1.04794
# Step 40000, Position: [ 0.235  -0.1485], Heading: 0.192, Metric real: 0.63998, Metric imag: 1.04055
# Step 41000, Position: [ 0.1055 -0.1434], Heading: 0.193, Metric real: 0.65441, Metric imag: 1.01440
# Step 42000, Position: [ 0.1394 -0.1059], Heading: 0.194, Metric real: 0.64508, Metric imag: 0.99251
# Step 43000, Position: [ 0.0044 -0.0949], Heading: 0.198, Metric real: 0.63699, Metric imag: 0.96348
# Step 44000, Position: [ 0.273  -0.0072], Heading: 0.191, Metric real: 0.62060, Metric imag: 0.92764
# Step 45000, Position: [0.2827 0.0251], Heading: 0.191, Metric real: 0.60145, Metric imag: 0.88740
# Step 46000, Position: [ 0.0093 -0.001 ], Heading: 0.184, Metric real: 0.57996, Metric imag: 0.85867
# Step 47000, Position: [0.2877 0.0692], Heading: 0.196, Metric real: 0.56306, Metric imag: 0.82416
# Step 48000, Position: [0.2624 0.0935], Heading: 0.174, Metric real: 0.53605, Metric imag: 0.81573
# Step 49000, Position: [0.2821 0.1344], Heading: 0.217, Metric real: 0.51416, Metric imag: 0.80799
# Step 50000, Position: [0.117  0.0984], Heading: -1.377, Metric real: 0.50306, Metric imag: 0.76864
# Step 51000, Position: [0.1258 0.0932], Heading: -1.378, Metric real: 0.49695, Metric imag: 0.72055
# Step 52000, Position: [0.1348 0.0943], Heading: -1.372, Metric real: 0.49528, Metric imag: 0.68526
# Step 53000, Position: [0.1434 0.0013], Heading: -1.366, Metric real: 0.49519, Metric imag: 0.66461
# Step 54000, Position: [ 0.2449 -0.2122], Heading: -2.948, Metric real: 0.47874, Metric imag: 0.68000
# Step 55000, Position: [ 0.2302 -0.2156], Heading: -2.946, Metric real: 0.46525, Metric imag: 0.70386
# Step 56000, Position: [ 0.2317 -0.2357], Heading: -2.946, Metric real: 0.45711, Metric imag: 0.73408
# Step 57000, Position: [ 0.2311 -0.2524], Heading: -2.944, Metric real: 0.45362, Metric imag: 0.76957
# Step 58000, Position: [ 0.2268 -0.2655], Heading: -2.941, Metric real: 0.45499, Metric imag: 0.80799
# Step 59000, Position: [ 0.1524 -0.2928], Heading: -2.913, Metric real: 0.46112, Metric imag: 0.84696
# Step 60000, Position: [0.1098 0.0576], Heading: -1.377, Metric real: 0.46315, Metric imag: 0.82504
# Step 61000, Position: [0.1111 0.0335], Heading: -1.381, Metric real: 0.46851, Metric imag: 0.80674
# Step 62000, Position: [ 0.1061 -0.008 ], Heading: -1.379, Metric real: 0.48035, Metric imag: 0.78869
# Step 63000, Position: [ 0.1019 -0.0408], Heading: -1.378, Metric real: 0.49904, Metric imag: 0.77029
# Step 64000, Position: [ 0.096  -0.0759], Heading: -1.372, Metric real: 0.52171, Metric imag: 0.75596
# Step 65000, Position: [ 0.0783 -0.1005], Heading: -1.373, Metric real: 0.54553, Metric imag: 0.74794
# Step 66000, Position: [ 0.0459 -0.1078], Heading: -1.368, Metric real: 0.56677, Metric imag: 0.74474
# Step 67000, Position: [ 0.0305 -0.1281], Heading: -1.376, Metric real: 0.58243, Metric imag: 0.74577
# Step 68000, Position: [ 0.0121 -0.13  ], Heading: -1.376, Metric real: 0.59218, Metric imag: 0.75130
# Step 69000, Position: [ 0.0003 -0.1453], Heading: -1.352, Metric real: 0.59632, Metric imag: 0.76057
# Step 70000, Position: [-0.0131 -0.1412], Heading: -1.364, Metric real: 0.59461, Metric imag: 0.77266
# Step 71000, Position: [-0.0277 -0.1456], Heading: -1.369, Metric real: 0.58549, Metric imag: 0.78608
# Step 72000, Position: [-0.0381 -0.144 ], Heading: -1.364, Metric real: 0.57247, Metric imag: 0.80097
# Step 73000, Position: [-0.0533 -0.1511], Heading: -1.365, Metric real: 0.55494, Metric imag: 0.81579
# Step 74000, Position: [-0.0654 -0.1512], Heading: -1.379, Metric real: 0.53322, Metric imag: 0.82971
# Step 75000, Position: [-0.0836 -0.1529], Heading: -1.354, Metric real: 0.50791, Metric imag: 0.84088
# Step 76000, Position: [-0.0951 -0.1575], Heading: -1.356, Metric real: 0.47991, Metric imag: 0.84793
# Step 77000, Position: [-0.109 -0.162], Heading: -1.350, Metric real: 0.45126, Metric imag: 0.84899
# Step 78000, Position: [-0.4856  0.1386], Heading: -1.201, Metric real: 0.44583, Metric imag: 0.82179
# Step 79000, Position: [0.4455 0.3211], Heading: -1.362, Metric real: 0.43942, Metric imag: 0.80892
# Step 80000, Position: [0.4534 0.3213], Heading: -1.365, Metric real: 0.43758, Metric imag: 0.79999
# Step 81000, Position: [0.4625 0.3162], Heading: -1.375, Metric real: 0.44002, Metric imag: 0.79466
# Step 82000, Position: [0.4542 0.2988], Heading: -1.371, Metric real: 0.44506, Metric imag: 0.79303
# Step 83000, Position: [0.446  0.2841], Heading: -1.367, Metric real: 0.45094, Metric imag: 0.79447
# Step 84000, Position: [0.4406 0.2657], Heading: -1.366, Metric real: 0.45681, Metric imag: 0.79778
# Step 85000, Position: [0.4362 0.2475], Heading: -1.367, Metric real: 0.46238, Metric imag: 0.80208
# Step 86000, Position: [ 0.3459 -0.4248], Heading: -0.634, Metric real: 0.45802, Metric imag: 0.80929
# Step 87000, Position: [ 0.3461 -0.425 ], Heading: -0.612, Metric real: 0.45027, Metric imag: 0.82193
# Step 88000, Position: [ 0.3379 -0.42  ], Heading: -0.577, Metric real: 0.44515, Metric imag: 0.83762
# Step 89000, Position: [ 0.3326 -0.4181], Heading: -0.520, Metric real: 0.44237, Metric imag: 0.85626
# Step 90000, Position: [ 0.3227 -0.4151], Heading: -0.425, Metric real: 0.44172, Metric imag: 0.87751
# Step 91000, Position: [ 0.3029 -0.4119], Heading: -0.240, Metric real: 0.44287, Metric imag: 0.90093
# Step 92000, Position: [ 0.2703 -0.4129], Heading: -0.038, Metric real: 0.44562, Metric imag: 0.92524
# Step 93000, Position: [-0.1334 -0.3526], Heading: 0.189, Metric real: 0.43248, Metric imag: 0.93378
# Step 94000, Position: [-0.1254 -0.3587], Heading: 0.191, Metric real: 0.41502, Metric imag: 0.94050
# Step 95000, Position: [-0.1168 -0.3648], Heading: 0.192, Metric real: 0.40151, Metric imag: 0.95004
# Step 96000, Position: [-0.1026 -0.3695], Heading: 0.195, Metric real: 0.39179, Metric imag: 0.96201
# Step 97000, Position: [-0.1089 -0.3613], Heading: 0.199, Metric real: 0.38470, Metric imag: 0.97623
# Step 98000, Position: [-0.1136 -0.3378], Heading: 0.197, Metric real: 0.37488, Metric imag: 0.99316
# Step 99000, Position: [-0.1172 -0.3263], Heading: 0.189, Metric real: 0.36286, Metric imag: 1.01175
# Step 100000, Position: [-0.1267 -0.3032], Heading: 0.190, Metric real: 0.34950, Metric imag: 1.03119
# Step 101000, Position: [-0.1326 -0.2791], Heading: 0.192, Metric real: 0.33438, Metric imag: 1.04937
# Step 102000, Position: [-0.1319 -0.2583], Heading: 0.196, Metric real: 0.31970, Metric imag: 1.06577
# Step 103000, Position: [-0.1226 -0.2417], Heading: 0.200, Metric real: 0.30815, Metric imag: 1.08146
# Step 104000, Position: [ 0.2811 -0.1225], Heading: 0.187, Metric real: 0.30953, Metric imag: 1.08158
# Step 105000, Position: [ 0.2789 -0.1344], Heading: 0.193, Metric real: 0.31957, Metric imag: 1.07002
# Step 106000, Position: [ 0.2497 -0.1271], Heading: 0.189, Metric real: 0.33112, Metric imag: 1.06071
# Step 107000, Position: [ 0.2198 -0.1231], Heading: 0.193, Metric real: 0.34206, Metric imag: 1.05247
# Step 108000, Position: [ 0.1939 -0.1115], Heading: 0.214, Metric real: 0.35020, Metric imag: 1.04389
# Step 109000, Position: [-0.0635 -0.1439], Heading: 0.210, Metric real: 0.34953, Metric imag: 1.03450
# Step 110000, Position: [ 0.2401 -0.0429], Heading: 0.190, Metric real: 0.35424, Metric imag: 1.02469
# Step 111000, Position: [ 0.2197 -0.0252], Heading: 0.195, Metric real: 0.35535, Metric imag: 1.01249
# Step 112000, Position: [ 0.227  -0.0016], Heading: 0.196, Metric real: 0.35337, Metric imag: 0.99802
# Step 113000, Position: [0.2306 0.0223], Heading: 0.196, Metric real: 0.34927, Metric imag: 0.98199
# Step 114000, Position: [0.2214 0.035 ], Heading: 0.187, Metric real: 0.34294, Metric imag: 0.96461
# Step 115000, Position: [0.2208 0.054 ], Heading: 0.194, Metric real: 0.33484, Metric imag: 0.94616
# Step 116000, Position: [0.2216 0.0718], Heading: 0.193, Metric real: 0.32505, Metric imag: 0.92680
# Step 117000, Position: [0.2278 0.0919], Heading: 0.196, Metric real: 0.31413, Metric imag: 0.90672
# Step 118000, Position: [0.23   0.1103], Heading: 0.194, Metric real: 0.30281, Metric imag: 0.88643
# Step 119000, Position: [0.2277 0.1288], Heading: 0.188, Metric real: 0.29214, Metric imag: 0.86627
# Step 120000, Position: [0.2307 0.1478], Heading: 0.182, Metric real: 0.28335, Metric imag: 0.84701
# Step 121000, Position: [0.1244 0.1496], Heading: 0.140, Metric real: 0.27761, Metric imag: 0.82899
# Step 122000, Position: [0.0869 0.0301], Heading: -1.387, Metric real: 0.27257, Metric imag: 0.81301
# Step 123000, Position: [0.0786 0.0019], Heading: -1.384, Metric real: 0.26868, Metric imag: 0.80022
# Step 124000, Position: [ 0.2268 -0.181 ], Heading: -2.943, Metric real: 0.26782, Metric imag: 0.79195
# Step 125000, Position: [ 0.2124 -0.1752], Heading: -2.937, Metric real: 0.26360, Metric imag: 0.79692
# Step 126000, Position: [ 0.2145 -0.1786], Heading: -2.944, Metric real: 0.26147, Metric imag: 0.80231
# Step 127000, Position: [ 0.2181 -0.1892], Heading: -2.943, Metric real: 0.26009, Metric imag: 0.81005
# Step 128000, Position: [ 0.2207 -0.1994], Heading: -2.942, Metric real: 0.25940, Metric imag: 0.82010
# Step 129000, Position: [ 0.2221 -0.209 ], Heading: -2.940, Metric real: 0.25946, Metric imag: 0.83213
# Step 130000, Position: [ 0.2226 -0.2181], Heading: -2.934, Metric real: 0.26035, Metric imag: 0.84581
# Step 131000, Position: [ 0.2282 -0.2271], Heading: -2.933, Metric real: 0.26205, Metric imag: 0.86087
# Step 132000, Position: [0.0227 0.003 ], Heading: -1.382, Metric real: 0.26144, Metric imag: 0.85445
# Step 133000, Position: [0.0313 0.0047], Heading: -1.382, Metric real: 0.26031, Metric imag: 0.84023
# Step 134000, Position: [0.0399 0.0111], Heading: -1.380, Metric real: 0.26090, Metric imag: 0.82712
# Step 135000, Position: [ 0.0391 -0.0267], Heading: -1.388, Metric real: 0.26312, Metric imag: 0.81607
# Step 136000, Position: [ 0.0701 -0.2263], Heading: -1.364, Metric real: 0.26598, Metric imag: 0.81766
# Step 137000, Position: [ 0.0113 -0.0201], Heading: -1.392, Metric real: 0.26956, Metric imag: 0.81913
# Step 138000, Position: [ 0.0279 -0.1887], Heading: -1.361, Metric real: 0.27180, Metric imag: 0.82059
# Step 139000, Position: [-0.0055 -0.1611], Heading: -1.355, Metric real: 0.27454, Metric imag: 0.83145
# Step 140000, Position: [-0.0266 -0.1542], Heading: -1.356, Metric real: 0.27456, Metric imag: 0.84213
# Step 141000, Position: [-0.0369 -0.1501], Heading: -1.356, Metric real: 0.27350, Metric imag: 0.85276
# Step 142000, Position: [-0.0478 -0.1551], Heading: -1.349, Metric real: 0.27159, Metric imag: 0.86306
# Step 143000, Position: [-0.0565 -0.156 ], Heading: -1.346, Metric real: 0.26858, Metric imag: 0.87232
# Step 144000, Position: [-0.0698 -0.1501], Heading: -1.362, Metric real: 0.26493, Metric imag: 0.88066
# Step 145000, Position: [-0.078  -0.1569], Heading: -1.336, Metric real: 0.26035, Metric imag: 0.88703
# Step 146000, Position: [-0.0887 -0.1562], Heading: -1.328, Metric real: 0.25529, Metric imag: 0.89165
# Step 147000, Position: [-0.101  -0.1603], Heading: -1.320, Metric real: 0.24981, Metric imag: 0.89346
# Step 148000, Position: [-0.1196 -0.1504], Heading: -1.292, Metric real: 0.24407, Metric imag: 0.89171
# Step 149000, Position: [-0.0714 -0.0966], Heading: 0.200, Metric real: 0.23924, Metric imag: 0.88433
# Step 150000, Position: [0.3597 0.0198], Heading: 0.190, Metric real: 0.23878, Metric imag: 0.87731
# Step 151000, Position: [0.3602 0.0092], Heading: 0.189, Metric real: 0.23981, Metric imag: 0.87158
# Step 152000, Position: [0.336  0.0118], Heading: 0.189, Metric real: 0.24210, Metric imag: 0.86716
# Step 153000, Position: [ 0.1141 -0.013 ], Heading: 0.193, Metric real: 0.24408, Metric imag: 0.86215
# Step 154000, Position: [0.2962 0.0394], Heading: 0.171, Metric real: 0.24450, Metric imag: 0.85311
# Step 155000, Position: [0.2809 0.0704], Heading: 0.196, Metric real: 0.24316, Metric imag: 0.84975
# Step 156000, Position: [0.2741 0.0933], Heading: 0.190, Metric real: 0.24021, Metric imag: 0.84499
# Step 157000, Position: [0.2771 0.1126], Heading: 0.191, Metric real: 0.23673, Metric imag: 0.83968
# Step 158000, Position: [0.275  0.1284], Heading: 0.194, Metric real: 0.23339, Metric imag: 0.83419
# Step 159000, Position: [0.2733 0.1474], Heading: 0.187, Metric real: 0.23077, Metric imag: 0.82888
# Step 160000, Position: [0.2764 0.1663], Heading: 0.192, Metric real: 0.22929, Metric imag: 0.82390
# Step 161000, Position: [0.1009 0.1039], Heading: -1.377, Metric real: 0.22969, Metric imag: 0.81482
# Step 162000, Position: [0.109  0.0992], Heading: -1.374, Metric real: 0.23162, Metric imag: 0.79635
# Step 163000, Position: [ 0.2458 -0.2221], Heading: -2.944, Metric real: 0.22975, Metric imag: 0.79681
# Step 164000, Position: [ 0.2422 -0.2145], Heading: -2.944, Metric real: 0.22663, Metric imag: 0.80648
# Step 165000, Position: [ 0.2309 -0.2197], Heading: -2.944, Metric real: 0.22471, Metric imag: 0.81654
# Step 166000, Position: [ 0.2332 -0.2231], Heading: -2.940, Metric real: 0.22314, Metric imag: 0.82756
# Step 167000, Position: [ 0.2241 -0.2142], Heading: -2.939, Metric real: 0.22276, Metric imag: 0.83886
# Step 168000, Position: [ 0.2273 -0.2256], Heading: -2.934, Metric real: 0.22330, Metric imag: 0.85058
# Step 169000, Position: [ 0.2361 -0.2332], Heading: -2.946, Metric real: 0.22399, Metric imag: 0.86308
# Step 170000, Position: [ 0.2293 -0.2458], Heading: -2.938, Metric real: 0.22494, Metric imag: 0.87602
# Step 171000, Position: [ 0.2348 -0.2554], Heading: -2.933, Metric real: 0.22603, Metric imag: 0.88912
# Step 172000, Position: [ 0.2297 -0.2667], Heading: -2.929, Metric real: 0.22728, Metric imag: 0.90209
# Step 173000, Position: [ 0.2286 -0.2766], Heading: -2.933, Metric real: 0.22872, Metric imag: 0.91468
# Step 174000, Position: [ 0.2288 -0.2863], Heading: -2.931, Metric real: 0.23041, Metric imag: 0.92667
# Step 175000, Position: [0.0301 0.0022], Heading: -1.387, Metric real: 0.22945, Metric imag: 0.92179
# Step 176000, Position: [0.0382 0.0037], Heading: -1.386, Metric real: 0.22786, Metric imag: 0.91270
# Step 177000, Position: [0.0465 0.005 ], Heading: -1.388, Metric real: 0.22732, Metric imag: 0.90388
# Step 178000, Position: [0.0541 0.015 ], Heading: -1.385, Metric real: 0.22792, Metric imag: 0.89493
# Step 179000, Position: [ 0.093 -0.26 ], Heading: -1.370, Metric real: 0.22945, Metric imag: 0.88984
# Step 180000, Position: [ 0.0924 -0.2508], Heading: -1.369, Metric real: 0.23180, Metric imag: 0.88815
# Step 181000, Position: [ 0.0753 -0.2266], Heading: -1.367, Metric real: 0.23467, Metric imag: 0.88870
# Step 182000, Position: [ 0.0609 -0.2087], Heading: -1.374, Metric real: 0.23805, Metric imag: 0.89183
# Step 183000, Position: [ 0.0126 -0.0077], Heading: -1.397, Metric real: 0.23906, Metric imag: 0.88822
# Step 184000, Position: [0.0213 0.0082], Heading: -1.393, Metric real: 0.24002, Metric imag: 0.88109
# Step 185000, Position: [ 0.0619 -0.2574], Heading: -1.367, Metric real: 0.24178, Metric imag: 0.87593
# Step 186000, Position: [ 0.0636 -0.2587], Heading: -1.363, Metric real: 0.24341, Metric imag: 0.87817
# Step 187000, Position: [ 0.0442 -0.2277], Heading: -1.367, Metric real: 0.24525, Metric imag: 0.88303
# Step 188000, Position: [ 0.0297 -0.2086], Heading: -1.366, Metric real: 0.24710, Metric imag: 0.89033
# Step 189000, Position: [ 0.0091 -0.1959], Heading: -1.372, Metric real: 0.24880, Metric imag: 0.89937
# Step 190000, Position: [-0.007  -0.1835], Heading: -1.356, Metric real: 0.24926, Metric imag: 0.90960
# Step 191000, Position: [-0.02  -0.185], Heading: -1.357, Metric real: 0.24858, Metric imag: 0.92011
# Step 192000, Position: [-0.0345 -0.1732], Heading: -1.354, Metric real: 0.24688, Metric imag: 0.93043
# Step 193000, Position: [-0.0445 -0.176 ], Heading: -1.355, Metric real: 0.24444, Metric imag: 0.94032
# Step 194000, Position: [-0.0556 -0.1742], Heading: -1.345, Metric real: 0.24128, Metric imag: 0.94938
# Step 195000, Position: [-0.0654 -0.1746], Heading: -1.335, Metric real: 0.23750, Metric imag: 0.95732
# Step 196000, Position: [-0.0747 -0.1757], Heading: -1.341, Metric real: 0.23321, Metric imag: 0.96363
# Step 197000, Position: [-0.0909 -0.1688], Heading: -1.332, Metric real: 0.22854, Metric imag: 0.96773
# Step 198000, Position: [-0.1082 -0.1668], Heading: -1.325, Metric real: 0.22411, Metric imag: 0.96874
# Step 199000, Position: [-0.1217 -0.1671], Heading: -1.306, Metric real: 0.21921, Metric imag: 0.96677
# Step 200000, Position: [ 0.0284 -0.0794], Heading: 0.102, Metric real: 0.21523, Metric imag: 0.96199

# %%
#### Plot the results
coeffs = (ck_list_update  + 1j * ck_list_update_imag) / (tsteps * dt)
Z_rotated_padded = np.fft.ifft2(coeffs, norm = 'forward')
Z_rotated_padded = np.abs(Z_rotated_padded)
Z_rotated = np.fft.ifftshift(Z_rotated_padded)
Z_rotated = Z_rotated[idx_start:idx_end, idx_start:idx_end]
fig, (ax2) = plt.subplots(1, 1, figsize=(18, 5))
im2 = ax2.imshow(Z_rotated, extent=[-0.5, 0.5, -0.5, 0.5], origin='lower', cmap='viridis')
ax2.set_title('Fourier Rotated at μ_θ = π/3')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
plt.colorbar(im2, ax=ax2, label='Intensity')
plt.tight_layout()
plt.show()
## Check valid pdf
print(Z_rotated.sum() * dx * dy)
fig, axes = plt.subplots(1, 2, figsize=(9,5), dpi=70, tight_layout=True)
ax = axes[0]
ax.set_aspect('equal')
ax.set_xlim(-0.5, 0.5)
ax.set_ylim(-0.5, 0.5)
ax.set_title(f'Original PDF')
ax.contourf(X_orig, Y_orig, Z_target.reshape(X_orig.shape), cmap='Reds')
ax.plot(x_traj[::10, 0], x_traj[::10, 1], linestyle='-', marker='', color='k', alpha=0.2, label='Trajectory')
ax.plot(x_traj[0, 0], x_traj[0, 1], linestyle='', marker='o', markersize=15, color='C2', alpha=1.0, label='Initial state')
ax.legend(loc='upper right')

ax2 = axes[1]
ax2.set_aspect('equal')
ax.set_xlim(-0.5, 0.5)
ax.set_ylim(-0.5, 0.5)
ax2.set_title(f'Empirical Density')
ax2.contourf(X_orig, Y_orig,
             Z_rotated.reshape(X_orig.shape),
             cmap='Reds')
plt.tight_layout()
plt.show()
# Out:
# 1.0528777178138116

# %%
# Generate animation (takes about 1 minute)
from IPython.display import HTML
from matplotlib import animation

fig, ax = plt.subplots(1, 1, figsize=(6,7), dpi=70, tight_layout=True)
ax.set_aspect('equal')
ax.set_xlim(-.5, .5)
ax.set_ylim(-.5, .5)
ax.set_xlabel('X (m)')
ax.set_ylabel('Y (m)')
ax.contourf(X_orig, Y_orig, Z_target.reshape(X_orig.shape), cmap='Reds')

robot_traj, = ax.plot([], [], linestyle='-', marker='', color='k', alpha=0.2)
robot_state, = ax.plot(x_traj[0,0], x_traj[0,1], linestyle='', marker='o', markersize=15, color='C2')

def update_plot(frame):
    t = int(frame * 100)
    robot_state.set_data(
        np.array([x_traj[t][0]]), np.array([x_traj[t][1]])
    )
    robot_traj.set_data(
        x_traj[:t,0][::100], x_traj[:t,1][::100]
    )

    return robot_state, robot_traj,

ani = animation.FuncAnimation(fig, update_plot, frames=int(tsteps/100)-1, blit=True, interval=30, repeat=False)
video = ani.to_html5_video()
HTML(video)
# Out:
# <video width="420" height="490" controls autoplay>
#   <source type="video/mp4" src="...
